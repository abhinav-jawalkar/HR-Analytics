# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv')

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
# Data Preprocessing

# %%
# Identifying null/missing values --> If any value was missing in the dataset

# %%
df.head() # show the first five rows of the dataset
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
df.tail() # Last 5 rows
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 14994                  4             0     1                      0
# 14995                  2             0     0                      0
# 14996                  4             0     0                      0
# 14997                  5             0     0                      0
# 14998                  3             0     0                      0
#
#             dept  salary
# 14994    support  medium
# 14995      sales     low
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.isnull().sum()  # No null/missing values are present in the dataset
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
# If any null value was present
# df.dropna()

# %%
# Check if any duplicate record/rows are present in the dataset

# %%
df[df.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
# Data Correlation --> Relationship of one column with other columns
# Positive --> Relationship of two columns moving in the same direction, directly proportional
# Negative --> Inversely Proportional
# Zero --> Not related to each other
# -1 to +1  , 0.92, 0.63, 0.087

# %%
df.corr() # for correlation values
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.corr(), annot=True, cmap = 'Greens')
# Out:
# <AxesSubplot:>

# %%
df['satisfactoryLevel'].corr(df['lastEvaluation'])
# Out:
# 0.09518595371704293

# %%
# !pip install seaborn

# %%
# Data visualisation

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
a = ['dept','numberOfProjects','timeSpent.company','workAccident', 'promotionInLast5years','salary']

# %%
a
# Out:
# ['dept',
#  'numberOfProjects',
#  'timeSpent.company',
#  'workAccident',
#  'promotionInLast5years',
#  'salary']

# %%
fig = plt.subplots(figsize=(20,25)) # 20,25 --> Height and width, subplots -> creating multiple plots all at once
for i,j in enumerate(a): # enumerate() helps in extracting out the index value as well as the data
    # i --> index value
    # j --> data   i = 0, j = 'dept', i = 1, j = 'numberOfProjects',...
    plt.subplot(3,2,i+1)  # 3 --> no. of rows, 2 --> columns, 
    # (3,2,1) (3,2,2) (3,2,3) (3,2,4) (3,2,5) (3,2,6)
    sns.countplot(x = j, data = df, hue = 'left') # categorical data, it will show the plots in different colors
    plt.xticks(rotation = 90)
plt.show()

# %%
# attrition rate = no. of employees that are leaving/total no.

# %%
# Conclusion 
# Dept --> Support, technical and sales, hr dept has the most no. of employees that are leaving.
# Projects --> 3,4 no. of projects are the safest no. of projects that the company should give to their employees.
# Time spent --> 3-5 years is the most crucial time for the company.
# Work Accident --> Most of the employees that are leaving, haven't been involved in any work accident.
# Promotion --> This can be one of the biggest reasons, as almost all the employees that are leaving, haven't been promoted.
# Salary --> Most of the employees that are leaving are getting low/medium salary.
